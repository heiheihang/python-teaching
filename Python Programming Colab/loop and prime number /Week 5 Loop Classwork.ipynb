# %% [markdown]
# # Class Examples

# %% [markdown]
# ## Comparison of TABS

# %%
for i in range(5):
  print("I play roblox!")
  print("I play minecraft!")

# %%
for i in range(5):
  print("I play roblox!")
print("I play minecraft!")

# %% [markdown]
# ## More Tabs!

# %%
n = 1
for i in range(5):
  if(n % 2 == 0):
    print("n is even")
  else:
    print("n is odd")
  n = n + 1

# %% [markdown]
# ## Task 1: Naive Factorisation
# Given a number `n`, print out all of its factors!
#
# Hint: use `%` and `if`

# %%
n = 100
#Your Code Here

# %% [markdown]
# # While Loop

# %% [markdown]
# ## A very simple while lop

# %%
n = 0
while(n < 5):
  print(n)
  n = n + 1

# %% [markdown]
# ## A dubious while loop

# %%
n = 0
while(n < 5):
  print(n)

# %% [markdown]
# ## A thorough example

# %%
n = 0
while(n < 10):
  print(n)
  n = n + 2

# %% [markdown]
# ## Task 2
# `print("I play Mario Kart")` 10 times using a while loop

# %%
#Your Code Here

# %% [markdown]
# ## Task 3
#
# Calculate `2 + 3 + 4 + ... + 103` using while loop

# %%
#Your Code Here

# %% [markdown]
# ## Task 4
#
# Repeatedly multiply a number `n` until it is bigger than 2048

# %%
n = 2
#Your Code Here

# %% [markdown]
# # Homework

# %% [markdown]
# ## Task 1 Part 1: Once in a While
#
# Given an integer `n`, `print("once in a while")` for `n` times using while loop

# %%
n = 10
#Your Code Here

# %% [markdown]
# ## Task 1 Part 2: Four Times in a While
#
# Given an integer `n`, it repeats itself until it becomes a multiple of `4`
#
#
# *   if it is a multiple of `3`, ADD 9 to itself
# *   else add 7 to itself!
#
# Print out its value in every step

# %%
n = 3
#Your Code Here

# %% [markdown]
# ## Task 2 Part 1: Oops
#
# Given an integer `n`, we "visit" each number from `1`, `2`, to `n-1`, `n`.
#
#
#
# *   If the number is divisible by `5`, `print("oops")`
# *   If the number is divisible by `7`, `print("double oops")`
# *   If the number is divisible by both, `print("triple oops")`
#
# Do this in a while loop!

# %%
n = 100
#Your Code Here

# %% [markdown]
# ## Task 2 Part 2: This is difficult...
#
# Given an integer `n`, print all of its factors using a while loop

# %%
n = 100
#FOR LOOP VERSION
for i in range(100):
  if(n % i == 0):
    print(i)

#WHILE LOOP VERSION
#Your Code Here

# %% [markdown]
# Task 3 Part 1:
