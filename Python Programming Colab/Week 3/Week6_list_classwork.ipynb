# %% [markdown]
# # List

# %% [markdown]
# ## Basic List Properties

# %% [markdown]
# List is probably the most common "data structure" in python. A list `a` for example looks like:
#
# [1,3,5,3,2]
#
# We can initialize a list in the following manner:

# %%
a = [1,3,5,3,2]

# %% [markdown]
# If can access the first element of the list by (index of list starts with 0)

# %%
print(a[0])

# %% [markdown]
# ## Task 1
#
# Now it is your turn to print the last element of list `a`

# %%
#Your Code Here

# %% [markdown]
# ## Append Element to List
#
# We can add new elements to the list with `append`. For example, if we want to add 7 to the list `a`:

# %%
a.append(7)
print(a)

# %% [markdown]
# ## Length of List
#
# Finally we can sort the order of the elements in list `a` with `sort`. For example, if we want to sort the list `a`:

# %% [markdown]
# We can also check the length of the list with `len`. For example, if we want to know the length of list `a`, we can:

# %%
print(len(a))

# %% [markdown]
# ## Task 2
#
# It is your turn to print every element in a list! Remember you learn `for loop` as `for(n)` last week? What would `n` be if we want to visit every element in a list?

# %%
#Your Code Here

a = [1,4,5,2,3]

for i in range(len(a)):
  print(a[i])
# Out:
# 1
# 4
# 5
# 2
# 3

# %% [markdown]
# # Sorting a List

# %%
a.sort()
print(a)

# %% [markdown]
# ## Task 3
#
# Now it is your turn to make an amazing list. As you have learnt `for loop` last week, can you build a list with odd numbers from 1 to 100?
#
# (Hint: Use `append`, `if`, `%2==1`, and `range(100)`, `for`)

# %%
#Your Code Here

# %% [markdown]
# ## Remove Element from List
#
# If we want to remove the first element from the list, we can use `pop(0)`. We do `pop(n)` to remove the nth position of the list.

# %%
b = [1,2,3,4,5]
print(b)
b.pop(0)
print(b)

# %% [markdown]
# ## Task 4
#
# Now it's your turn to remove 4 from the following list `c`

# %%
c = [3,5,3,3,4,8,7]
#Your Code Here
