# %% [markdown]
# # Task 1
# Given an integer `n`, output a list of integers such that `n` is divisible by all its elements.
#
# For example:
#
# `n = 10`, `a = [1,2,5,10]`

# %%
#YOUR CODE HERE

# %% [markdown]
# # Task 2a
# Given a list `a`, print its smallest element

# %%
#YOUR CODE HERE

# %% [markdown]
# # Task 2b (Hard)
# Given a list `a`, print its most occured element:
#
# Example:
#
#
#
# ```
# a = [1,1,1,2,2,3]
# element = 1
# ```

# %%
a = [1,4,3,2,3,4,5,5,5]

# %% [markdown]
# # Task 3
# For a list `a`, find the maximum sum of two elements form the list.
#
# For example, `a = [3,5,8,1,2]`, largest sum is `5+8 = 13`

# %%
a = [3,5,8,1,2]

# %%
#YOUR CODE HERE

# %% [markdown]
# # Task 4
# For two sorted list `a` and `b`, build a new list `c` that is sorted AT EVERY SINGLE ITERATION.
#
# For example:
#
#
# ```
# a = [1,3,5]
# b = [2,6,8]
# c = [1] -> [1,2] -> [1,2,3] -> [1,2,3,5] -> [1,2,3,5,6] -> [1,2,3,5,6,8]
#
# ```

# %%
#YOUR CODE HERE

# %% [markdown]
# # Task 5
#
# Two integers `a` and `b` is considered as a `pair` if:
#
#
# *   `(a+b)%2 == 0`
#
# A `change` to a position of a list is defined as `s[i] = x` (new assignment to an element)
#
# Given a list `s` of even length (e.g. 2,4,6,8) with `2n` elements, determine the minimum number of changes needed such that we can form `n pairs` of integers in `s`
#
# For example:
#
# ```
# a = [1,2,5,9,8,4]
# change 1 to 2: [2,2,5,9,8,4]
# Pairs: (2,2), (5,9), (8,4)
# So the minimum change is 1
# ```

# %%
#a = [7,5,4,4,4,3,2,1,1,2,6,7,8,6,5,4,3,5]
#Your Code Here
