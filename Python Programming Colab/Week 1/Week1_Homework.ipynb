# %% [markdown]
# **If you are confident, go to the bottom and start doing exercises in the TASK section!**
#
# Let's remind yourself how to "print" some strings (remember strings are sequences of characters!)
#
# For example, if we want to print "Hello, World!", we write:
#
# (Hold shift -> enter or press the run button to run the cell below)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# We have also learnt arithmetic in Python. You may be wondering why I have int(d) instead of d in the print statement. Experiment yourself with division and print out x/y and see what happens!

# %%
x = 10
y = 5

a = x + y # a = 10 + 5 = 15
b = x - y # b = 10 - 5 = 5
c = x * y # c = 10 * 5 = 50
d = x / y # d = 10 / 5 = 2

print(a,b,c,int(d))
# Out:
# 15 5 50 2

# %% [markdown]
# We have also learnt modulo, which simply gives the remainder of a division.
#
# For example:
#
# 10 % 3 = 1 (10 = 3*3 + 1)
#
# 20 % 4 = 0 (20 = 5*4 + 0)
#
# 23 % 4 = 3 (23 = 5*4 + 3)
#
# 24 % 4 = 0 (24 = 6*4 + 0)

# %%
print(10%3)
print(20%4)
print(23%4)
print(24%4)
# Out:
# 1
# 0
# 3
# 0

# %% [markdown]
# The last thing we learnt was if-else. We can for example use the following if-else to check if variable x is 0 or not.
#
# **REMEMBER TO USE == INSTEAD OF = IN IF-ELSE**

# %%
print("when x is 0, the if-else gives us:")
x = 0

if(x == 0):
  print("x is 0")
else:
  print("x is not 0")

print("------------------------------------------------------")

print("when x is 1, the if-else gives us:")
x = 1

if(x == 0):
  print("x is 0")
else:
  print("x is not 0")
# Out:
# when x is 0, the if-else gives us:
# x is 0
# ------------------------------------------------------
# when x is 1, the if-else gives us:
# x is not 0

# %% [markdown]
# # Homework

# %% [markdown]
# ## Task 1: Magic Swap
# Given two integers `a` and `b`, can you swap the values in `a` and `b`?
#
# For example `a=30`, `b=20`, can you swap `a` and `b` such that `a=20` and `b=30`?

# %%
a = 30
b = 20 #For example

#Your Code Here

# %% [markdown]
# ## Task 2: Uncolored Blocks
# Given a cube of length `n` constiting of `n**3` `1x1` blocks , all of its surface blocks are painted in Green! Calculate the number of blocks that are not painted in green!

# %%
n = 20 # for example

#Your Code Here

# %% [markdown]
# ## Task 3: This looks familiar...
# Given an odd integer `n`, print the sum of `1+2+3+...+n`
#
# Also print the sum of `1+3+5+7+...+n`

# %%
n = 51 #for example

#Your Code Here

# %% [markdown]
# # Task 4: Divisibility Problem
#
# You are given two positive integers 𝑎 and 𝑏. In one move you can increase 𝑎 by 1 (replace 𝑎 with 𝑎+1). Your task is to find the minimum number of moves you need to do in order to make 𝑎 divisible by 𝑏. It is possible, that you have to make 0 moves, as 𝑎 is already divisible by 𝑏. You have to answer 𝑡 independent test cases.
#
# Source: **CodeForces**

# %%
a = 30
b = 9

#Your Code Here

# %% [markdown]
# ## Task 5: Donut Shop (**Challenging**)
#
# There are two donut shops, shop A and shop B.
#
# In shop A, they only sell **one** donut to all customers at price `a`.
#
# In shop B, they only sell **one box** **bold text** of `b` donuts to all customers at price `c`
#
# If you want to buy 𝑥 donuts from this shop, then you have to buy the smallest number of boxes such that the total number of donuts in them is greater or equal to 𝑥.
#
# You need to output two results:
#
#
# *   How many donuts do we need to buy at shop A so that it is strictly cheaper than at shop B
# *   How many donuts do we need to buy at shop B so that it is strictly cheaper than at shop A
#
# If any of these values doesn't exist then that value should be equal to −1. If there are multiple possible answers, then print any of them.
#
# Source: **CodeForces**

# %%
a = 15
b = 3
c = 20

#Your Code Here
