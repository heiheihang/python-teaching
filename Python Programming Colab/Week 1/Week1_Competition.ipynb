# %% [markdown]
# # Competition
# You have 45 minutes to complete this competition.

# %% [markdown]
# # Task 1: Candies for the Two Sisters
# I have `n` candies and I want to distribute `n` candies to two sisters, Alice and Betty. I will distribute the `n` candies following these rules:
#
#
#
# 1.   Alice will get more candies than Betty
# 2.   They will get an INTEGER number of candies
# 3.   All candies will be given to the two sisters.
# 4.   Both of them will at least get one candies (thus `n > 2`)
#
# Print out the number of ways the candies can be distributed among the two sisters.
#
# e.g. 6 candies: (5,1), (4,2), 2 ways

# %%
n = 53 #for example
#Your Code Here

# %% [markdown]
# # Task 2: FizzBuzz Count
# Given two integers `x` and `y`, and a given range limit `n`, print the number of integers less than `n` that are a multiple of `x` or `y`.
#
# For example, if `x=3`, `y=5`, `n=20`, the integers that satisfy the requirement are: `3,5,6,9,10,12,15,18`, so you should output `8`.

# %%
x = 3
y = 5
n = 20 
#For example
#Your Code Here

# %% [markdown]
# # Task 3: Monstrous Sum
# Given two numbers `x` and `n`, you will need to determine if `x**0 + x**1 + x**2 + ... + x**n` is even or not. Print `even` is it is even, print `odd` otherwise.
#
# For example, given `x=3` and `n=3`, `3**0 + 3**1 + 3**2 + 3**3` is even.

# %%
x = 5
n = 4 #for example
#Your Code Here

# %% [markdown]
# # Task 4: Odd-Happy
# Given a number of candies `n`, and a number of students `m`, determine if it is possible to distribute the candies such that each student gets an odd number of candies.
#
# For example if `n = 20`, `m = 4`, it is possible to give each students `5` candies each, so they are all odd-happy!

# %%
n = 20
m = 4
#for example

# %% [markdown]
# # Task 5: Special Regular Polygon
# For a regular polygon of n sides, it defintely can be rotated for one side to be parallel to the y-axis, or the x-axis. There are some regular polygons that can be rotated such that there will be at least two sides parallel to the y-axis AND x-axis. Square is an example.
#
# Given a regular polygon with side n, print "Special Polygon" if it satisfies the property that it has 2 sides parallel to x-axis and y-axis. Otherwise, print "Not a Special Polygon".
#
# For example, a square can have 2 sides parallel to the x-axis and the y-axis. It is a special polygon!
