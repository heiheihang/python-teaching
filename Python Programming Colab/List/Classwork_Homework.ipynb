# %% [markdown]
# # Task 1 Part 1: HEAD-ache
#
# Given a list, you need to print its first element in the format of `a[x]`
#
# For example, `a = [5,3,6,7,8]`, you should print out `5` with `print(a[x])` where `x` is an integer

# %%
a = [7,4,2,5,7,8]

#Your Code Here

# %% [markdown]
# # Task 1 Part 2: Everyone!
#
# Print out every element in the list.
#
# For example, `a = [4,2,2,3]`, you should print out
#
#
# *   4
# *   2
# *   2
# *   3
#
# Hint: You will need a `for` loop, potentially `len` to complete this.

# %%
a = [3,5,3,2]

# %% [markdown]
# # Task 2 Part 1: Odd...Even...Odd Odd Even
#
# Given a list of integers
#
#
# *   `print("odd")` if the number is odd
# *   `print("even"` if the number is even
#
# For example, if `a = [2,5,5,7,4]`
#
#
# *   `print("even")` (because `2` is even)
# *   `print("odd")` (because `5` is odd)
# *   `print("odd")` (because `5` is odd)
# *   `print("odd")` (because `7` is evodden)
# *   `print("even")` (because `4` is even)
#
# Hint: `for`, `if`, `%`

# %%
a = [6,4,7,7,9,10,4]

#Your Code Here

# %% [markdown]
# # Task 2 Part 2: Odd/Even list
#
# Given a list of integers, create two lists such that one only stores even number and the other only stores odd numbers.
#
# For example, given a list `a = [4,4,6,7,8,4]`
#
#
# *   `even = [4,4,6,8,4]`
# *   `odd = [7]`
#
# Hint1: `for`, `if`, `%`, `append`
#
# Hint2: `a.append(x)` adds `x` to the list `a`

# %%
a = [4,3,6,7,8,10,13,15]
even = []
odd = []

#Your Code Here

# %% [markdown]
# # Task 3 Part 1: Smaller!
#
# Given a list `a`, if an element is smaller than its previous element, print it out! (For the first element, you can decide print it out or not)
#
# For example, `a = [4,3,10,5,11]`
#
#
#
# *   3 (3 < 4)
# *   5 (5 < 10)
#
# Hint1: You will need `for`, `if`, `range`, `len`
#
# Hint2: You will need an extra variable to "remember" the previous element

# %%
a = [10,3,2,11,9,4,13]

#Your Code Here
