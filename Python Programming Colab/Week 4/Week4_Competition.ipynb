# %% [markdown]
# # Task 1
# Given a list `a` consisting of `1` and `0`. Each `1` and `0` determins the persons vote to pass a proposal. Determine if a proposal should be passed.
#
# If the number of `1` equals `0`, the tradition is to pass the proposal, and we will follow that tradition.

# %%
a = [1,0,0,1,1,1,0,1,1,0,0,0]
#Your Code Here

# %% [markdown]
# # Task 2
#
# A frog jumps left and right on a number line. On each step the frog either jumps `a` steps to the left and `b` steps to the right. Given that the frog jumps `a` steps to the left first, and then jumps `b` steps to the right, and then jumps `a` steps to the left. Give the location of the frog after 100 jumps.
#
# Credits: https://codeforces.com/problemset/problem/1077/A

# %%
a = 5
b = 7
#Your Code Here

# %% [markdown]
# # Task 3
# Given a list `a` of even length `2n` consisting of the programming skill levels of students. The coach wants to form `n` teams such that each team has 2 students with the same programming skill level.
#
# It happens that many students have different skill levels, and the coach can provide a problem to a student to increase his/her programming skill level by 1.
#
# Output the minimum number of problems the coach needs to prepare in order to form `n` teams.
#
# Credits: https://codeforces.com/problemset/problem/1092/B

# %%
a = [10,3,14,2,9,7,16,18]

# %% [markdown]
# # Task 4
# Given a list `a` of `1` and `0` , if we have 01 or 10 as two consecutive numbers, we remove them, repeatedly until we reach the end of the list.
#
# For example:
#
# ```
# a = [1,0,1,1,1,0]
# a = [1,1,1,0]
# a = [1,1]
# ```
# Hint: You will use one of the data structures you learnt today

# %%
a = [1,0,1,1,1,0,0,1,0,1,0,0,0,1,1,0,0,1]
#Your Code Here

# %% [markdown]
# # Task 5
